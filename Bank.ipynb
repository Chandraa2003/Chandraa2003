# %%
def bank_operation():
  ac_num = 12345678
  ac_name = "Chandra Suranjana"
  account_number = int(input('Enter account number:'))
  balance = 0
  for i in range (10):
    while account_number != ac_num:
       account_number = int(input('Enter correct account number:'))
       print ('Account number is incorrect.Please try again.')
       continue

    if ac_num == account_number:
      print ("Welcome Chandra")
      print ("Please choose your option:")
      print ("1.Deposit")
      print ("2.Withdraw")
      print ("3.Check Balance")
      print ("4.Exit")

    choice = int (input (' Enter your option:'))

    if choice == 1:
      deposit = float (input (f'Enter deposit amount:'))
      balance = balance + deposit
      print (f'Your current balance is {balance}')

    if choice == 2:
      withdraw = float (input (f'Enter withdraw amount:'))
      if withdraw > balance:
        print ('Insufficient Balance')
      else:
        balance = balance - withdraw
        print (f'You have successfully withdrawn {withdraw}.Your current balance is : {balance}')

    elif choice == 3:
      print (f'Your current balance is {balance}')


    if choice == 4:
      print ('Thank you for banking with us')
      break


    elif choice not in [1,2,3,4]:
       print (f'Please choose correct option.')

bank_operation()
# Out:
# Enter account number:12345678
# Welcome Chandra
# Please choose your option:
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Exit
#  Enter your option:1
# Enter deposit amount:10000
# Your current balance is 10000.0
# Welcome Chandra
# Please choose your option:
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Exit
#  Enter your option:2
# Enter withdraw amount:2000
# You have successfully withdrawn 2000.0.Your current balance is : 8000.0
# Welcome Chandra
# Please choose your option:
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Exit
#  Enter your option:3
# Your current balance is 8000.0
# Welcome Chandra
# Please choose your option:
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Exit
#  Enter your option:5
# Please choose correct option.
# Welcome Chandra
# Please choose your option:
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Exit
#  Enter your option:4
# Thank you for banking with us
